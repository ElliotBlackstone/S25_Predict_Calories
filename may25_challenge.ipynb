# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math as math
from sklearn.linear_model import LinearRegression
from sklearn.metrics import root_mean_squared_log_error as rmsle
from sklearn.metrics import root_mean_squared_error as rmse
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer, accuracy_score
from sklearn.model_selection import KFold
import lightgbm as lgb

# %%
train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")
sample = pd.read_csv("sample_submission.csv")

train.head()
# Out:
#    id     Sex  Age  Height  Weight  Duration  Heart_Rate  Body_Temp  Calories
# 0   0    male   36   189.0    82.0      26.0       101.0       41.0     150.0
# 1   1  female   64   163.0    60.0       8.0        85.0       39.7      34.0
# 2   2  female   51   161.0    64.0       7.0        84.0       39.8      29.0
# 3   3    male   20   192.0    90.0      25.0       105.0       40.7     140.0
# 4   4  female   38   166.0    61.0      25.0       102.0       40.6     146.0

# %%
noncat = ['Age', 'Height', 'Weight', 'Duration', 'Heart_Rate', 'Body_Temp']

train[noncat+['Calories']].corr()
# Out:
#                  Age    Height    Weight  Duration  Heart_Rate  Body_Temp  \
# Age         1.000000  0.011975  0.073690  0.015656    0.017037   0.030275
# Height      0.011975  1.000000  0.957967 -0.029936   -0.013234  -0.034641
# Weight      0.073690  0.957967  1.000000 -0.020845   -0.002384  -0.023717
# Duration    0.015656 -0.029936 -0.020845  1.000000    0.875327   0.903066
# Heart_Rate  0.017037 -0.013234 -0.002384  0.875327    1.000000   0.795972
# Body_Temp   0.030275 -0.034641 -0.023717  0.903066    0.795972   1.000000
# Calories    0.145683 -0.004026  0.015863  0.959908    0.908748   0.828671
#
#             Calories
# Age         0.145683
# Height     -0.004026
# Weight      0.015863
# Duration    0.959908
# Heart_Rate  0.908748
# Body_Temp   0.828671
# Calories    1.000000

# %%
y = train['Calories']

X = train.drop(columns=['id', 'Calories'])
X['Sex'] = X['Sex'].astype('category')

# %%
number_leaves = [256,512,1024]
learning_rate = [0.25,0.2,0.1,0.05]
number_boosts = [100,150,200]

model_err = {}

for nl in number_leaves:
    for lr in learning_rate:
        for nbr in number_boosts:

            # Initialize KFold
            kf = KFold(n_splits=5, shuffle=True)

            # Initialize a list to collect accuracy scores
            scores = []

            # Iterate over each fold
            for train_index, test_index in kf.split(X):

                X_train, X_test = X.loc[train_index], X.loc[test_index]
                y_train, y_test = y.loc[train_index], y.loc[test_index]

                dtrain = lgb.Dataset(X_train, label=y_train)

                
                # Define parameters
                params = {
                    'num_leaves': nl,
                    'learning_rate': lr,
                    'objective': 'regression',  # LightGBM doesn't have squaredlogerror directly
                    'metric': 'rmse',           # 
                    'force_col_wise': True,     # Optional: can help with categorical support
                    'verbose': -1
                }

                # Initialize and train the model
                model = lgb.train(params, dtrain, num_boost_round=nbr, feval=rmsle)


                # Predict and evaluate the model
                y_pred = model.predict(X_test)
                y_pred[y_pred <= 0] = 10
                score = rmsle(y_test, y_pred)
                scores.append(score)

            
            # Output the mean accuracy over all folds
            print(f"Mean Accuracy for num_leaves={nl}, learn_rate={lr}, num_boost={nbr}: {np.mean(scores)}")

            model_err[f"num_leaves_{nl}_learn_rate_{lr}_num_boost_{nbr}"] = np.mean(scores)

# Find the key with the minimum value
min_key = min(model_err, key=model_err.get)

# Retrieve the minimum value
min_value = model_err[min_key]

# Print the result
print(f"The key with the minimum value is '{min_key}' with a value of {min_value}.")
# Out:
# Mean Accuracy for num_leaves=256, learn_rate=0.25, num_boost=100: 0.06298387323167917
# Mean Accuracy for num_leaves=256, learn_rate=0.25, num_boost=150: 0.06264885271634295
# Mean Accuracy for num_leaves=256, learn_rate=0.25, num_boost=200: 0.06272394614664804
# Mean Accuracy for num_leaves=256, learn_rate=0.2, num_boost=100: 0.06287490513258431
# Mean Accuracy for num_leaves=256, learn_rate=0.2, num_boost=150: 0.06248318198933304
# Mean Accuracy for num_leaves=256, learn_rate=0.2, num_boost=200: 0.06235730078706109
# Mean Accuracy for num_leaves=256, learn_rate=0.1, num_boost=100: 0.06221927638581076
# Mean Accuracy for num_leaves=256, learn_rate=0.1, num_boost=150: 0.06203367081814927
# Mean Accuracy for num_leaves=256, learn_rate=0.1, num_boost=200: 0.06179718921563746
# Mean Accuracy for num_leaves=256, learn_rate=0.05, num_boost=100: 0.06984597117399424
# Mean Accuracy for num_leaves=256, learn_rate=0.05, num_boost=150: 0.06227538252840157
# Mean Accuracy for num_leaves=256, learn_rate=0.05, num_boost=200: 0.061894517783287764
# Mean Accuracy for num_leaves=512, learn_rate=0.25, num_boost=100: 0.062713891205096
# Mean Accuracy for num_leaves=512, learn_rate=0.25, num_boost=150: 0.06294752620977342
# Mean Accuracy for num_leaves=512, learn_rate=0.25, num_boost=200: 0.06300125192278516
# Mean Accuracy for num_leaves=512, learn_rate=0.2, num_boost=100: 0.06231330012203638
# Mean Accuracy for num_leaves=512, learn_rate=0.2, num_boost=150: 0.062280375021943835
# Mean Accuracy for num_leaves=512, learn_rate=0.2, num_boost=200: 0.062388112499882055
# Mean Accuracy for num_leaves=512, learn_rate=0.1, num_boost=100: 0.06189789021898199
# Mean Accuracy for num_leaves=512, learn_rate=0.1, num_boost=150: 0.061471373692634224
# Mean Accuracy for num_leaves=512, learn_rate=0.1, num_boost=200: 0.06137688591827817
# Mean Accuracy for num_leaves=512, learn_rate=0.05, num_boost=100: 0.06832157584107228
# Mean Accuracy for num_leaves=512, learn_rate=0.05, num_boost=150: 0.0617553741824393
# Mean Accuracy for num_leaves=512, learn_rate=0.05, num_boost=200: 0.06118887612479361
# Mean Accuracy for num_leaves=1024, learn_rate=0.25, num_boost=100: 0.06287427546977503
# Mean Accuracy for num_leaves=1024, learn_rate=0.25, num_boost=150: 0.06328221323204357
# Mean Accuracy for num_leaves=1024, learn_rate=0.25, num_boost=200: 0.06364667011925128
# Mean Accuracy for num_leaves=1024, learn_rate=0.2, num_boost=100: 0.06237628916804686
# Mean Accuracy for num_leaves=1024, learn_rate=0.2, num_boost=150: 0.06256796921478149
# Mean Accuracy for num_leaves=1024, learn_rate=0.2, num_boost=200: 0.06290680606136437
# Mean Accuracy for num_leaves=1024, learn_rate=0.1, num_boost=100: 0.061297471963239245
# Mean Accuracy for num_leaves=1024, learn_rate=0.1, num_boost=150: 0.06137433102140501
# Mean Accuracy for num_leaves=1024, learn_rate=0.1, num_boost=200: 0.06177885881395684
# Mean Accuracy for num_leaves=1024, learn_rate=0.05, num_boost=100: 0.0675638460392185
# Mean Accuracy for num_leaves=1024, learn_rate=0.05, num_boost=150: 0.061414271988864344
# Mean Accuracy for num_leaves=1024, learn_rate=0.05, num_boost=200: 0.06129509413735079
# The key with the minimum value is 'num_leaves_512_learn_rate_0.05_num_boost_200' with a value of 0.06118887612479361.

# %%
number_leaves = [400,450,500,550,600,2000]
learning_rate = [0.1,0.05,0.01]
number_boosts = [100,150,200,500]

model_err = {}

for nl in number_leaves:
    for lr in learning_rate:
        for nbr in number_boosts:

            # Initialize KFold
            kf = KFold(n_splits=5, shuffle=True)

            # Initialize a list to collect accuracy scores
            scores = []

            # Iterate over each fold
            for train_index, test_index in kf.split(X):

                X_train, X_test = X.loc[train_index], X.loc[test_index]
                y_train, y_test = y.loc[train_index], y.loc[test_index]

                dtrain = lgb.Dataset(X_train, label=y_train)

                
                # Define parameters
                params = {
                    'num_leaves': nl,
                    'learning_rate': lr,
                    'objective': 'regression',  # LightGBM doesn't have squaredlogerror directly
                    'metric': 'rmse',           # 
                    'force_col_wise': True,     # Optional: can help with categorical support
                    'verbose': -1
                }

                # Initialize and train the model
                model = lgb.train(params, dtrain, num_boost_round=nbr, feval=rmsle)


                # Predict and evaluate the model
                y_pred = model.predict(X_test)
                y_pred[y_pred <= 0] = 10
                score = rmsle(y_test, y_pred)
                scores.append(score)

            
            # Output the mean accuracy over all folds
            print(f"Mean Accuracy for num_leaves={nl}, learn_rate={lr}, num_boost={nbr}: {np.mean(scores)}")

            model_err[f"num_leaves_{nl}_learn_rate_{lr}_num_boost_{nbr}"] = np.mean(scores)

# Find the key with the minimum value
min_key = min(model_err, key=model_err.get)

# Retrieve the minimum value
min_value = model_err[min_key]

# Print the result
print(f"The key with the minimum value is '{min_key}' with a value of {min_value}.")
# Out:
# Mean Accuracy for num_leaves=400, learn_rate=0.1, num_boost=100: 0.06172022837194215
# Mean Accuracy for num_leaves=400, learn_rate=0.1, num_boost=150: 0.06159082570807878
# Mean Accuracy for num_leaves=400, learn_rate=0.1, num_boost=200: 0.061367608656331674
# Mean Accuracy for num_leaves=400, learn_rate=0.1, num_boost=500: 0.061554679274835225
# Mean Accuracy for num_leaves=400, learn_rate=0.05, num_boost=100: 0.0689139080400792
# Mean Accuracy for num_leaves=400, learn_rate=0.05, num_boost=150: 0.061640187889388354
# Mean Accuracy for num_leaves=400, learn_rate=0.05, num_boost=200: 0.06141746213337258
# Mean Accuracy for num_leaves=400, learn_rate=0.05, num_boost=500: 0.06131750476205483
# Mean Accuracy for num_leaves=400, learn_rate=0.01, num_boost=100: 0.5939138089927378
# Mean Accuracy for num_leaves=400, learn_rate=0.01, num_boost=150: 0.44449032530303534
# Mean Accuracy for num_leaves=400, learn_rate=0.01, num_boost=200: 0.326374340043051
# Mean Accuracy for num_leaves=400, learn_rate=0.01, num_boost=500: 0.06989265231303521
# Mean Accuracy for num_leaves=450, learn_rate=0.1, num_boost=100: 0.06159997479834277
# Mean Accuracy for num_leaves=450, learn_rate=0.1, num_boost=150: 0.06155809402677327
# Mean Accuracy for num_leaves=450, learn_rate=0.1, num_boost=200: 0.06150226864533359
# Mean Accuracy for num_leaves=450, learn_rate=0.1, num_boost=500: 0.06157563536911
# Mean Accuracy for num_leaves=450, learn_rate=0.05, num_boost=100: 0.0687280769275003
# Mean Accuracy for num_leaves=450, learn_rate=0.05, num_boost=150: 0.06154324322506214
# Mean Accuracy for num_leaves=450, learn_rate=0.05, num_boost=200: 0.06133513656570937
# Mean Accuracy for num_leaves=450, learn_rate=0.05, num_boost=500: 0.06132780261538543
# Mean Accuracy for num_leaves=450, learn_rate=0.01, num_boost=100: 0.5937220468793845
# Mean Accuracy for num_leaves=450, learn_rate=0.01, num_boost=150: 0.44422429589425716
# Mean Accuracy for num_leaves=450, learn_rate=0.01, num_boost=200: 0.3259998511026856
# Mean Accuracy for num_leaves=450, learn_rate=0.01, num_boost=500: 0.0698487064397364
# Mean Accuracy for num_leaves=500, learn_rate=0.1, num_boost=100: 0.06155138376710416
# Mean Accuracy for num_leaves=500, learn_rate=0.1, num_boost=150: 0.06153278093427307
# Mean Accuracy for num_leaves=500, learn_rate=0.1, num_boost=200: 0.061473490250873244
# Mean Accuracy for num_leaves=500, learn_rate=0.1, num_boost=500: 0.061665312646840796
# Mean Accuracy for num_leaves=500, learn_rate=0.05, num_boost=100: 0.0685001923689387
# Mean Accuracy for num_leaves=500, learn_rate=0.05, num_boost=150: 0.061560899468047624
# Mean Accuracy for num_leaves=500, learn_rate=0.05, num_boost=200: 0.06131222160601633
# Mean Accuracy for num_leaves=500, learn_rate=0.05, num_boost=500: 0.0612618299993713
# Mean Accuracy for num_leaves=500, learn_rate=0.01, num_boost=100: 0.5935763973916982
# Mean Accuracy for num_leaves=500, learn_rate=0.01, num_boost=150: 0.4439547452592391
# Mean Accuracy for num_leaves=500, learn_rate=0.01, num_boost=200: 0.3256310023435833
# Mean Accuracy for num_leaves=500, learn_rate=0.01, num_boost=500: 0.0696010289002447
# Mean Accuracy for num_leaves=550, learn_rate=0.1, num_boost=100: 0.06141815965054367
# Mean Accuracy for num_leaves=550, learn_rate=0.1, num_boost=150: 0.06164384766813373
# Mean Accuracy for num_leaves=550, learn_rate=0.1, num_boost=200: 0.061395215742519535
# Mean Accuracy for num_leaves=550, learn_rate=0.1, num_boost=500: 0.06168944337799247
# Mean Accuracy for num_leaves=550, learn_rate=0.05, num_boost=100: 0.06836671140318072
# Mean Accuracy for num_leaves=550, learn_rate=0.05, num_boost=150: 0.0616210001865138
# Mean Accuracy for num_leaves=550, learn_rate=0.05, num_boost=200: 0.061393665409849106
# Mean Accuracy for num_leaves=550, learn_rate=0.05, num_boost=500: 0.06105985151833684
# Mean Accuracy for num_leaves=550, learn_rate=0.01, num_boost=100: 0.5934317283340554
# Mean Accuracy for num_leaves=550, learn_rate=0.01, num_boost=150: 0.44374623059052587
# Mean Accuracy for num_leaves=550, learn_rate=0.01, num_boost=200: 0.32535174261152383
# Mean Accuracy for num_leaves=550, learn_rate=0.01, num_boost=500: 0.06944015896893148
# Mean Accuracy for num_leaves=600, learn_rate=0.1, num_boost=100: 0.061561027346131135
# Mean Accuracy for num_leaves=600, learn_rate=0.1, num_boost=150: 0.06161307422290356
# Mean Accuracy for num_leaves=600, learn_rate=0.1, num_boost=200: 0.061603595988684756
# Mean Accuracy for num_leaves=600, learn_rate=0.1, num_boost=500: 0.061934080422790395
# Mean Accuracy for num_leaves=600, learn_rate=0.05, num_boost=100: 0.0680878069227506
# Mean Accuracy for num_leaves=600, learn_rate=0.05, num_boost=150: 0.061684143900554746
# Mean Accuracy for num_leaves=600, learn_rate=0.05, num_boost=200: 0.06129873632147757
# Mean Accuracy for num_leaves=600, learn_rate=0.05, num_boost=500: 0.06118234784040647
# Mean Accuracy for num_leaves=600, learn_rate=0.01, num_boost=100: 0.5932950380672211
# Mean Accuracy for num_leaves=600, learn_rate=0.01, num_boost=150: 0.44353655820317883
# Mean Accuracy for num_leaves=600, learn_rate=0.01, num_boost=200: 0.32509068766375115
# Mean Accuracy for num_leaves=600, learn_rate=0.01, num_boost=500: 0.06925648402916411
# Mean Accuracy for num_leaves=2000, learn_rate=0.1, num_boost=100: 0.06164692393335812
# Mean Accuracy for num_leaves=2000, learn_rate=0.1, num_boost=150: 0.06160457770453467
# Mean Accuracy for num_leaves=2000, learn_rate=0.1, num_boost=200: 0.06184903629872408
# Mean Accuracy for num_leaves=2000, learn_rate=0.1, num_boost=500: 0.06336892834190042
# Mean Accuracy for num_leaves=2000, learn_rate=0.05, num_boost=100: 0.06688240829573933
# Mean Accuracy for num_leaves=2000, learn_rate=0.05, num_boost=150: 0.06109135412238316
# Mean Accuracy for num_leaves=2000, learn_rate=0.05, num_boost=200: 0.06115198880901389
# Mean Accuracy for num_leaves=2000, learn_rate=0.05, num_boost=500: 0.061931214766898536
# Mean Accuracy for num_leaves=2000, learn_rate=0.01, num_boost=100: 0.5922017890104005
# Mean Accuracy for num_leaves=2000, learn_rate=0.01, num_boost=150: 0.441882271983639
# Mean Accuracy for num_leaves=2000, learn_rate=0.01, num_boost=200: 0.3228331990055348
# Mean Accuracy for num_leaves=2000, learn_rate=0.01, num_boost=500: 0.06794802374045546
# The key with the minimum value is 'num_leaves_550_learn_rate_0.05_num_boost_500' with a value of 0.06105985151833684.

# %%
X_train = train.sample(n=600000, random_state=212)
y_train = X_train['Calories']

X_train.drop(columns=['id', 'Calories'], inplace=True)
X_train['Sex'] = X_train['Sex'].astype('category')

X_train.head()
# Out:
#            Sex  Age  Height  Weight  Duration  Heart_Rate  Body_Temp
# 637285    male   40   182.0    85.0      16.0        91.0       40.2
# 137087  female   30   158.0    64.0      10.0        90.0       40.2
# 11662     male   54   184.0    87.0       3.0        82.0       38.8
# 83022   female   61   186.0    81.0      25.0       106.0       40.7
# 405249  female   40   169.0    69.0      11.0        99.0       39.9

# %%
# Kaggle score 0.0????

dtrain = lgb.Dataset(X_train, label=y_train)

# Define parameters
params = {
    'num_leaves': 550,
    'learning_rate': 0.05,
    'objective': 'regression',  # LightGBM doesn't have squaredlogerror directly
    'metric': 'rmse',           # We'll manually compute RMSLE
    'force_col_wise': True,     # Optional: can help with categorical support
}

# Train the model
model = lgb.train(params, dtrain, num_boost_round=500, feval=rmsle)

# Make predictions
test_pred = model.predict(X_train)

# Ensure non-negative predictions (important for RMSLE)
test_pred[test_pred < 0] = 10

print(rmsle(test_pred, y_train))
# Out:
# 0.0558775389208406

# %%
# Kaggle score 0.06023

dtrain = lgb.Dataset(X_train, label=y_train)

# Define parameters
params = {
    'num_leaves': 512,
    'learning_rate': 0.05,
    'objective': 'regression',  # LightGBM doesn't have squaredlogerror directly
    'metric': 'rmse',           # We'll manually compute RMSLE
    'force_col_wise': True,     # Optional: can help with categorical support
}

# Train the model
model = lgb.train(params, dtrain, num_boost_round=150)

# Make predictions
test_pred = model.predict(X_train)

# Ensure non-negative predictions (important for RMSLE)
test_pred[test_pred < 0] = 10

print(rmsle(test_pred, y_train))
# Out:
# 0.05900664667015287

# %%
# Kaggle score 0.06950

dtrain = lgb.Dataset(X_train, label=y_train)

# Define parameters
params = {
    'num_leaves': 4096,
    'learning_rate': 0.25,
    'objective': 'regression',  # LightGBM doesn't have squaredlogerror directly
    'metric': 'rmse',           # We'll manually compute RMSLE
    'force_col_wise': True,     # Optional: can help with categorical support
}

# Train the model
model = lgb.train(params, dtrain, num_boost_round=800)

# Make predictions
test_pred = model.predict(X_train)

# Ensure non-negative predictions (important for RMSLE)
test_pred[test_pred < 0] = 0

print(rmsle(test_pred, y_train))
# Out:
# [LightGBM] [Info] Total Bins 360
# [LightGBM] [Info] Number of data points in the train set: 600000, number of used features: 7
# [LightGBM] [Info] Start training from score 88.259470
# 0.012886190162029899

# %%
# Kaggle score 0.06451

dtrain = lgb.Dataset(X_train, label=y_train)

# Define parameters
params = {
    'num_leaves': 4096,
    'learning_rate': 0.2,
    'objective': 'regression',  # LightGBM doesn't have squaredlogerror directly
    'metric': 'rmse',           # We'll manually compute RMSLE
    'force_col_wise': True,     # Optional: can help with categorical support
}

# Train the model
model = lgb.train(params, dtrain, num_boost_round=250)

# Make predictions
test_pred = model.predict(X_train)

# Ensure non-negative predictions (important for RMSLE)
test_pred[test_pred < 0] = 0

print(rmsle(test_pred, y_train))
# Out:
# [LightGBM] [Info] Total Bins 360
# [LightGBM] [Info] Number of data points in the train set: 600000, number of used features: 7
# [LightGBM] [Info] Start training from score 88.259470
# 0.035241875337224664

# %%
# Kaggle score 0.06149

dtrain = lgb.Dataset(X_train, label=y_train)

# Define parameters
params = {
    'num_leaves': 4096,
    'learning_rate': 0.05,
    'objective': 'regression',  # LightGBM doesn't have squaredlogerror directly
    'metric': 'rmse',           # We'll manually compute RMSLE
    'force_col_wise': True,     # Optional: can help with categorical support
}

# Train the model
model = lgb.train(params, dtrain, num_boost_round=250)

# Make predictions
test_pred = model.predict(X_train)

# Ensure non-negative predictions (important for RMSLE)
test_pred[test_pred < 0] = 0

print(rmsle(test_pred, y_train))
# Out:
# [LightGBM] [Info] Total Bins 360
# [LightGBM] [Info] Number of data points in the train set: 600000, number of used features: 7
# [LightGBM] [Info] Start training from score 88.259470
# 0.051208862654664705

# %%
# Kaggle score 0.06309

dtrain = lgb.Dataset(X_train, label=y_train)

# Define parameters
params = {
    'num_leaves': 2048,
    'learning_rate': 0.2,
    'objective': 'regression',  # LightGBM doesn't have squaredlogerror directly
    'metric': 'rmse',           # We'll manually compute RMSLE
    'force_col_wise': True,     # Optional: can help with categorical support
}

# Train the model
model = lgb.train(params, dtrain, num_boost_round=250)

# Make predictions
test_pred = model.predict(X_train)

# Ensure non-negative predictions (important for RMSLE)
test_pred[test_pred < 0] = 0

print(rmsle(test_pred, y_train))
# Out:
# [LightGBM] [Info] Total Bins 360
# [LightGBM] [Info] Number of data points in the train set: 600000, number of used features: 7
# [LightGBM] [Info] Start training from score 88.259470
# 0.044682788102133095

# %%
# Kaggle score 0.?

dtrain = lgb.Dataset(X_train, label=np.log1p(y_train))

# Define parameters
params = {
    'num_leaves': 1024,
    'learning_rate': 0.2,
    'objective': 'regression',  # LightGBM doesn't have squaredlogerror directly
    'metric': 'rmse',           # We'll manually compute RMSLE
    'force_col_wise': True,     # Optional: can help with categorical support
}

# Train the model
model = lgb.train(params, dtrain, num_boost_round=250)

# Make predictions
test_pred = np.expm1(model.predict(X_train))

# Ensure non-negative predictions (important for RMSLE)
test_pred[test_pred < 0] = 0

print(rmsle(test_pred, y_train))
# Out:
# [LightGBM] [Info] Total Bins 360
# [LightGBM] [Info] Number of data points in the train set: 600000, number of used features: 7
# [LightGBM] [Info] Start training from score 4.141099
# 0.03827713295897256

# %%
test.drop(columns=['id'], inplace=True)

test['Sex'] = test['Sex'].astype('category')

test.head()
# Out:
#       Sex  Age  Height  Weight  Duration  Heart_Rate  Body_Temp
# 0    male   45   177.0    81.0       7.0        87.0       39.8
# 1    male   26   200.0    97.0      20.0       101.0       40.5
# 2  female   29   188.0    85.0      16.0       102.0       40.4
# 3  female   39   172.0    73.0      20.0       107.0       40.6
# 4  female   30   173.0    67.0      16.0        94.0       40.5

# %%
# make the submission file!

pred = model.predict(test)

submission = pd.DataFrame()

submission['id'] = np.arange(len(test))+750000
submission['Calories'] = pred
submission.loc[submission['Calories'] < 0, 'Calories'] = 10

submission.to_csv("lgb_prediction_7.csv", index=False)

print(submission.head())
print()
print(submission['Calories'].describe())
# Out:
#        id    Calories
# 0  750000   27.400827
# 1  750001  106.850966
# 2  750002   86.877382
# 3  750003  125.862741
# 4  750004   76.543693
#
# count    250000.000000
# mean         88.249042
# std          62.289379
# min           1.006235
# 25%          34.128223
# 50%          76.533263
# 75%         135.451640
# max         303.868214
# Name: Calories, dtype: float64
