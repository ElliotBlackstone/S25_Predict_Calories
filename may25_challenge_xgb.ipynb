# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math as math
from sklearn.linear_model import LinearRegression
from sklearn.metrics import root_mean_squared_log_error as rmsle
from sklearn.metrics import root_mean_squared_error as rmse
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer, accuracy_score
from sklearn.model_selection import KFold
import lightgbm as lgb
import xgboost as xgb
import itertools

# %%
train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")
# sample = pd.read_csv("sample_submission.csv")

train.head()
# Out:
#    id     Sex  Age  Height  Weight  Duration  Heart_Rate  Body_Temp  Calories
# 0   0    male   36   189.0    82.0      26.0       101.0       41.0     150.0
# 1   1  female   64   163.0    60.0       8.0        85.0       39.7      34.0
# 2   2  female   51   161.0    64.0       7.0        84.0       39.8      29.0
# 3   3    male   20   192.0    90.0      25.0       105.0       40.7     140.0
# 4   4  female   38   166.0    61.0      25.0       102.0       40.6     146.0

# %%
noncat = ['Age', 'Height', 'Weight', 'Duration', 'Heart_Rate', 'Body_Temp']

train[noncat + ['Calories']].corr()
# Out:
#                  Age    Height    Weight  Duration  Heart_Rate  Body_Temp  \
# Age         1.000000  0.011975  0.073690  0.015656    0.017037   0.030275
# Height      0.011975  1.000000  0.957967 -0.029936   -0.013234  -0.034641
# Weight      0.073690  0.957967  1.000000 -0.020845   -0.002384  -0.023717
# Duration    0.015656 -0.029936 -0.020845  1.000000    0.875327   0.903066
# Heart_Rate  0.017037 -0.013234 -0.002384  0.875327    1.000000   0.795972
# Body_Temp   0.030275 -0.034641 -0.023717  0.903066    0.795972   1.000000
# Calories    0.145683 -0.004026  0.015863  0.959908    0.908748   0.828671
#
#             Calories
# Age         0.145683
# Height     -0.004026
# Weight      0.015863
# Duration    0.959908
# Heart_Rate  0.908748
# Body_Temp   0.828671
# Calories    1.000000

# %%
y = train['Calories']

X = train.drop(columns=['id', 'Calories'])
X['Sex'] = X['Sex'].astype('category')

X['BMI'] = X['Weight']/((X['Height']/100)**2)
X['Intensity'] = X['Duration']*X['Heart_Rate']

X.head()
# Out:
#       Sex  Age  Height  Weight  Duration  Heart_Rate  Body_Temp        BMI  \
# 0    male   36   189.0    82.0      26.0       101.0       41.0  22.955684
# 1  female   64   163.0    60.0       8.0        85.0       39.7  22.582709
# 2  female   51   161.0    64.0       7.0        84.0       39.8  24.690405
# 3    male   20   192.0    90.0      25.0       105.0       40.7  24.414062
# 4  female   38   166.0    61.0      25.0       102.0       40.6  22.136740
#
#    Intensity
# 0     2626.0
# 1      680.0
# 2      588.0
# 3     2625.0
# 4     2550.0

# %%
max_depth = [10,12]
learning_rate = [0.1, 0.05, 0.02]
number_boosts = [100, 1000]
subsamp = [0.9, 1]

model_err = {}

for md, lr, nbr, ss in itertools.product(max_depth, learning_rate, number_boosts, subsamp):
    # Initialize KFold
    kf = KFold(n_splits=5, shuffle=True)

    # Initialize a list to collect accuracy scores
    scores = []

    # Iterate over each fold
    for train_index, test_index in kf.split(X):

        X_train, X_test = X.loc[train_index], X.loc[test_index]
        y_train, y_test = y.loc[train_index], y.loc[test_index]

        dtrain = xgb.DMatrix(X_train, label=y_train, enable_categorical=True) 

                
        # Define parameters
        params = {
            'max_depth': md,
            'eta': lr,                           # learning rate
            'objective': 'reg:squaredlogerror',  # 
            'subsample': ss,                     # subsample rate
            'device': 'cuda'
        }

        # Initialize and train the model
        model = xgb.train(params, dtrain, num_boost_round=nbr)


        # Predict and evaluate the model
        y_pred = model.predict(xgb.DMatrix(X_test, enable_categorical=True))
        y_pred[y_pred <= 0] = 10
        score = rmsle(y_test, y_pred)
        scores.append(score)

            
    # Output the mean accuracy over all folds
    print(f"Mean Accuracy for max_depth={md}, learn_rate={lr}, num_boost={nbr}, subsample={ss}: {np.mean(scores)}")

    model_err[f"max_depth_{md}_learn_rate_{lr}_num_boost_{nbr}_subsample_{ss}"] = np.mean(scores)

# Find the key with the minimum value
min_key = min(model_err, key=model_err.get)

# Retrieve the minimum value
min_value = model_err[min_key]

# Print the result
print(f"The key with the minimum value is '{min_key}' with a value of {min_value}.")
# Out:
# Mean Accuracy for max_depth=10, learn_rate=0.1, num_boost=100, subsample=0.9: 0.08712032640656196
# Mean Accuracy for max_depth=10, learn_rate=0.1, num_boost=100, subsample=1: 0.08593389439009799
# Mean Accuracy for max_depth=10, learn_rate=0.1, num_boost=1000, subsample=0.9: 0.06341848979606227
# Mean Accuracy for max_depth=10, learn_rate=0.1, num_boost=1000, subsample=1: 0.06327652293058057
# Mean Accuracy for max_depth=10, learn_rate=0.05, num_boost=100, subsample=0.9: 0.7329423184610636
# Mean Accuracy for max_depth=10, learn_rate=0.05, num_boost=100, subsample=1: 0.7323792443788555
# Mean Accuracy for max_depth=10, learn_rate=0.05, num_boost=1000, subsample=0.9: 0.06411701500723425
# Mean Accuracy for max_depth=10, learn_rate=0.05, num_boost=1000, subsample=1: 0.06396488711495237
# Mean Accuracy for max_depth=10, learn_rate=0.02, num_boost=100, subsample=0.9: 2.2721793471539735
# Mean Accuracy for max_depth=10, learn_rate=0.02, num_boost=100, subsample=1: 2.2721596746571535
# Mean Accuracy for max_depth=10, learn_rate=0.02, num_boost=1000, subsample=0.9: 0.06713993990373365
# Mean Accuracy for max_depth=10, learn_rate=0.02, num_boost=1000, subsample=1: 0.06633097381720796
# Mean Accuracy for max_depth=12, learn_rate=0.1, num_boost=100, subsample=0.9: 0.08706558668916935
# Mean Accuracy for max_depth=12, learn_rate=0.1, num_boost=100, subsample=1: 0.08567301113288218
# Mean Accuracy for max_depth=12, learn_rate=0.1, num_boost=1000, subsample=0.9: 0.06360070826673361
# Mean Accuracy for max_depth=12, learn_rate=0.1, num_boost=1000, subsample=1: 0.0633066050684417
# Mean Accuracy for max_depth=12, learn_rate=0.05, num_boost=100, subsample=0.9: 0.7329714384746111
# Mean Accuracy for max_depth=12, learn_rate=0.05, num_boost=100, subsample=1: 0.7323724158648679
# Mean Accuracy for max_depth=12, learn_rate=0.05, num_boost=1000, subsample=0.9: 0.06411033176413583
# Mean Accuracy for max_depth=12, learn_rate=0.05, num_boost=1000, subsample=1: 0.06403568319061693
# Mean Accuracy for max_depth=12, learn_rate=0.02, num_boost=100, subsample=0.9: 2.2721914021294247
# Mean Accuracy for max_depth=12, learn_rate=0.02, num_boost=100, subsample=1: 2.2721670345148177
# Mean Accuracy for max_depth=12, learn_rate=0.02, num_boost=1000, subsample=0.9: 0.06696731797567146
# Mean Accuracy for max_depth=12, learn_rate=0.02, num_boost=1000, subsample=1: 0.06623778575141406
# The key with the minimum value is 'max_depth_10_learn_rate_0.1_num_boost_1000_subsample_1' with a value of 0.06327652293058057.

# %%
max_depth = [25, 50]
learning_rate = [0.1, 0.05]
number_boosts = [100, 150]
subsamp = [0.75, 1]

model_err = {}

for md, lr, nbr, ss in itertools.product(max_depth, learning_rate, number_boosts, subsamp):
    # Initialize KFold
    kf = KFold(n_splits=5, shuffle=True)

    # Initialize a list to collect accuracy scores
    scores = []

    # Iterate over each fold
    for train_index, test_index in kf.split(X):

        X_train, X_test = X.loc[train_index], X.loc[test_index]
        y_train, y_test = y.loc[train_index], y.loc[test_index]

        dtrain = xgb.DMatrix(X_train, label=y_train, enable_categorical=True) 

                
        # Define parameters
        params = {
            'max_depth': md,
            'eta': lr,                           # learning rate
            'objective': 'reg:squaredlogerror',  # 
            'subsample': ss,                     # subsample rate
            #'device': 'cuda'
        }

        # Initialize and train the model
        model = xgb.train(params, dtrain, num_boost_round=nbr)


        # Predict and evaluate the model
        y_pred = model.predict(xgb.DMatrix(X_test, enable_categorical=True))
        y_pred[y_pred <= 0] = 10
        score = rmsle(y_test, y_pred)
        scores.append(score)

            
    # Output the mean accuracy over all folds
    print(f"Mean Accuracy for max_depth={md}, learn_rate={lr}, num_boost={nbr}, subsample={ss}: {np.mean(scores)}")

    model_err[f"max_depth_{md}_learn_rate_{lr}_num_boost_{nbr}_subsample_{ss}"] = np.mean(scores)

# Find the key with the minimum value
min_key = min(model_err, key=model_err.get)

# Retrieve the minimum value
min_value = model_err[min_key]

# Print the result
print(f"The key with the minimum value is '{min_key}' with a value of {min_value}.")
# Out:
# Mean Accuracy for max_depth=25, learn_rate=0.1, num_boost=100, subsample=0.75: 0.08906362807584735
# Mean Accuracy for max_depth=25, learn_rate=0.1, num_boost=100, subsample=1: 0.0853231350492397
# Mean Accuracy for max_depth=25, learn_rate=0.1, num_boost=150, subsample=0.75: 0.07076738667215557
# Mean Accuracy for max_depth=25, learn_rate=0.1, num_boost=150, subsample=1: 0.06845480815950662
# Mean Accuracy for max_depth=25, learn_rate=0.05, num_boost=100, subsample=0.75: 0.7339933313752841
# Mean Accuracy for max_depth=25, learn_rate=0.05, num_boost=100, subsample=1: 0.7323663754278312
# Mean Accuracy for max_depth=25, learn_rate=0.05, num_boost=150, subsample=0.75: 0.18861005111910173
# Mean Accuracy for max_depth=25, learn_rate=0.05, num_boost=150, subsample=1: 0.1834401854216608
# Mean Accuracy for max_depth=50, learn_rate=0.1, num_boost=100, subsample=0.75: 0.08914222158197238
# Mean Accuracy for max_depth=50, learn_rate=0.1, num_boost=100, subsample=1: 0.0853739650273311
# Mean Accuracy for max_depth=50, learn_rate=0.1, num_boost=150, subsample=0.75: 0.07094814867681938
# Mean Accuracy for max_depth=50, learn_rate=0.1, num_boost=150, subsample=1: 0.06865634077835894
# Mean Accuracy for max_depth=50, learn_rate=0.05, num_boost=100, subsample=0.75: 0.7339758215031665
# Mean Accuracy for max_depth=50, learn_rate=0.05, num_boost=100, subsample=1: 0.7323639415521928
# Mean Accuracy for max_depth=50, learn_rate=0.05, num_boost=150, subsample=0.75: 0.18860976379693845
# Mean Accuracy for max_depth=50, learn_rate=0.05, num_boost=150, subsample=1: 0.18346781766747702
# The key with the minimum value is 'max_depth_25_learn_rate_0.1_num_boost_150_subsample_1' with a value of 0.06845480815950662.

# %%
max_depth = [8, 12, 16, 18, 24, 28]
learning_rate = [0.15, 0.1, 0.05]
number_boosts = [100, 150, 200, 250]
subsamp = [0.75, 1]

model_err = {}

for md, lr, nbr, ss in itertools.product(max_depth, learning_rate, number_boosts, subsamp):
    # Initialize KFold
    kf = KFold(n_splits=5, shuffle=True)

    # Initialize a list to collect accuracy scores
    scores = []

    # Iterate over each fold
    for train_index, test_index in kf.split(X):

        X_train, X_test = X.loc[train_index], X.loc[test_index]
        y_train, y_test = y.loc[train_index], y.loc[test_index]

        dtrain = xgb.DMatrix(X_train, label=y_train, enable_categorical=True) 

                
        # Define parameters
        params = {
            'max_depth': md,
            'eta': lr,                           # learning rate
            'objective': 'reg:squaredlogerror',  # 
            'subsample': ss,                     # subsample rate
            'device': 'cuda'
        }

        # Initialize and train the model
        model = xgb.train(params, dtrain, num_boost_round=nbr)


        # Predict and evaluate the model
        y_pred = model.predict(xgb.DMatrix(X_test, enable_categorical=True))
        y_pred[y_pred <= 0] = 10
        score = rmsle(y_test, y_pred)
        scores.append(score)

            
    # Output the mean accuracy over all folds
    print(f"Mean Accuracy for max_depth={md}, learn_rate={lr}, num_boost={nbr}, subsample={ss}: {np.mean(scores)}")

    model_err[f"max_depth_{md}_learn_rate_{lr}_num_boost_{nbr}_subsample_{ss}"] = np.mean(scores)

# Find the key with the minimum value
min_key = min(model_err, key=model_err.get)

# Retrieve the minimum value
min_value = model_err[min_key]

# Print the result
print(f"The key with the minimum value is '{min_key}' with a value of {min_value}.")
# Out:
# Mean Accuracy for max_depth=8, learn_rate=0.15, num_boost=100, subsample=0.75: 0.07194357376315377
# Mean Accuracy for max_depth=8, learn_rate=0.15, num_boost=100, subsample=1: 0.06934903626847051
# Mean Accuracy for max_depth=8, learn_rate=0.15, num_boost=150, subsample=0.75: 0.06821757533943433
# Mean Accuracy for max_depth=8, learn_rate=0.15, num_boost=150, subsample=1: 0.06633057883795905
# Mean Accuracy for max_depth=8, learn_rate=0.15, num_boost=200, subsample=0.75: 0.06674479386545246
# Mean Accuracy for max_depth=8, learn_rate=0.15, num_boost=200, subsample=1: 0.06538101143602114
# Mean Accuracy for max_depth=8, learn_rate=0.15, num_boost=250, subsample=0.75: 0.06601546688831539
# Mean Accuracy for max_depth=8, learn_rate=0.15, num_boost=250, subsample=1: 0.06478614795553084
# Mean Accuracy for max_depth=8, learn_rate=0.1, num_boost=100, subsample=0.75: 0.0900015177462287
# Mean Accuracy for max_depth=8, learn_rate=0.1, num_boost=100, subsample=1: 0.08637327296938552
# Mean Accuracy for max_depth=8, learn_rate=0.1, num_boost=150, subsample=0.75: 0.07159576379184276
# Mean Accuracy for max_depth=8, learn_rate=0.1, num_boost=150, subsample=1: 0.06921930704929523
# Mean Accuracy for max_depth=8, learn_rate=0.1, num_boost=200, subsample=0.75: 0.06884995584658186
# Mean Accuracy for max_depth=8, learn_rate=0.1, num_boost=200, subsample=1: 0.06661129360179732
# Mean Accuracy for max_depth=8, learn_rate=0.1, num_boost=250, subsample=0.75: 0.06742494592169228
# Mean Accuracy for max_depth=8, learn_rate=0.1, num_boost=250, subsample=1: 0.06581524547426851
# Mean Accuracy for max_depth=8, learn_rate=0.05, num_boost=100, subsample=0.75: 0.7340026990590569
# Mean Accuracy for max_depth=8, learn_rate=0.05, num_boost=100, subsample=1: 0.7323833002320335
# Mean Accuracy for max_depth=8, learn_rate=0.05, num_boost=150, subsample=0.75: 0.1890203999552122
# Mean Accuracy for max_depth=8, learn_rate=0.05, num_boost=150, subsample=1: 0.18395316858604632
# Mean Accuracy for max_depth=8, learn_rate=0.05, num_boost=200, subsample=0.75: 0.08925788984796543
# Mean Accuracy for max_depth=8, learn_rate=0.05, num_boost=200, subsample=1: 0.08580702491348367
# Mean Accuracy for max_depth=8, learn_rate=0.05, num_boost=250, subsample=0.75: 0.07460971856265522
# Mean Accuracy for max_depth=8, learn_rate=0.05, num_boost=250, subsample=1: 0.072078542993519
# Mean Accuracy for max_depth=12, learn_rate=0.15, num_boost=100, subsample=0.75: 0.07117671028996717
# Mean Accuracy for max_depth=12, learn_rate=0.15, num_boost=100, subsample=1: 0.06859241703949547
# Mean Accuracy for max_depth=12, learn_rate=0.15, num_boost=150, subsample=0.75: 0.06769585760509181
# Mean Accuracy for max_depth=12, learn_rate=0.15, num_boost=150, subsample=1: 0.0659235819297406
# Mean Accuracy for max_depth=12, learn_rate=0.15, num_boost=200, subsample=0.75: 0.0666698874939721
# Mean Accuracy for max_depth=12, learn_rate=0.15, num_boost=200, subsample=1: 0.0650232328813238
# Mean Accuracy for max_depth=12, learn_rate=0.15, num_boost=250, subsample=0.75: 0.0658136014307563
# Mean Accuracy for max_depth=12, learn_rate=0.15, num_boost=250, subsample=1: 0.06473298139001629
# Mean Accuracy for max_depth=12, learn_rate=0.1, num_boost=100, subsample=0.75: 0.08947656588117774
# Mean Accuracy for max_depth=12, learn_rate=0.1, num_boost=100, subsample=1: 0.0857502714910873
# Mean Accuracy for max_depth=12, learn_rate=0.1, num_boost=150, subsample=0.75: 0.07123820291056801
# Mean Accuracy for max_depth=12, learn_rate=0.1, num_boost=150, subsample=1: 0.06842684300047938
# Mean Accuracy for max_depth=12, learn_rate=0.1, num_boost=200, subsample=0.75: 0.06825269212843305
# Mean Accuracy for max_depth=12, learn_rate=0.1, num_boost=200, subsample=1: 0.06634384508116672
# Mean Accuracy for max_depth=12, learn_rate=0.1, num_boost=250, subsample=0.75: 0.0670996840518719
# Mean Accuracy for max_depth=12, learn_rate=0.1, num_boost=250, subsample=1: 0.06529542940996134
# Mean Accuracy for max_depth=12, learn_rate=0.05, num_boost=100, subsample=0.75: 0.7340292728479981
# Mean Accuracy for max_depth=12, learn_rate=0.05, num_boost=100, subsample=1: 0.7323287479350481
# Mean Accuracy for max_depth=12, learn_rate=0.05, num_boost=150, subsample=0.75: 0.18876895049078604
# Mean Accuracy for max_depth=12, learn_rate=0.05, num_boost=150, subsample=1: 0.18365986906794124
# Mean Accuracy for max_depth=12, learn_rate=0.05, num_boost=200, subsample=0.75: 0.08878589929918093
# Mean Accuracy for max_depth=12, learn_rate=0.05, num_boost=200, subsample=1: 0.08515428393251126
# Mean Accuracy for max_depth=12, learn_rate=0.05, num_boost=250, subsample=0.75: 0.07412754871759572
# Mean Accuracy for max_depth=12, learn_rate=0.05, num_boost=250, subsample=1: 0.07134443980505142
# Mean Accuracy for max_depth=16, learn_rate=0.15, num_boost=100, subsample=0.75: 0.0714062623068452
# Mean Accuracy for max_depth=16, learn_rate=0.15, num_boost=100, subsample=1: 0.06873322767839529
# Mean Accuracy for max_depth=16, learn_rate=0.15, num_boost=150, subsample=0.75: 0.06786854601520007
# Mean Accuracy for max_depth=16, learn_rate=0.15, num_boost=150, subsample=1: 0.06572484356979429
# Mean Accuracy for max_depth=16, learn_rate=0.15, num_boost=200, subsample=0.75: 0.06668087531670623
# Mean Accuracy for max_depth=16, learn_rate=0.15, num_boost=200, subsample=1: 0.06493653692661336
# Mean Accuracy for max_depth=16, learn_rate=0.15, num_boost=250, subsample=0.75: 0.06593589324206457
# Mean Accuracy for max_depth=16, learn_rate=0.15, num_boost=250, subsample=1: 0.06452192395398305
# Mean Accuracy for max_depth=16, learn_rate=0.1, num_boost=100, subsample=0.75: 0.08946610886661241
# Mean Accuracy for max_depth=16, learn_rate=0.1, num_boost=100, subsample=1: 0.08579948025933051
# Mean Accuracy for max_depth=16, learn_rate=0.1, num_boost=150, subsample=0.75: 0.07106587126037804
# Mean Accuracy for max_depth=16, learn_rate=0.1, num_boost=150, subsample=1: 0.06838662185702335
# Mean Accuracy for max_depth=16, learn_rate=0.1, num_boost=200, subsample=0.75: 0.06828035595384696
# Mean Accuracy for max_depth=16, learn_rate=0.1, num_boost=200, subsample=1: 0.06621885343171936
# Mean Accuracy for max_depth=16, learn_rate=0.1, num_boost=250, subsample=0.75: 0.06709807027345516
# Mean Accuracy for max_depth=16, learn_rate=0.1, num_boost=250, subsample=1: 0.0653175762630976
# Mean Accuracy for max_depth=16, learn_rate=0.05, num_boost=100, subsample=0.75: 0.7340536168203504
# Mean Accuracy for max_depth=16, learn_rate=0.05, num_boost=100, subsample=1: 0.7323403806867956
# Mean Accuracy for max_depth=16, learn_rate=0.05, num_boost=150, subsample=0.75: 0.18875932653313537
# Mean Accuracy for max_depth=16, learn_rate=0.05, num_boost=150, subsample=1: 0.18367287984742284
# Mean Accuracy for max_depth=16, learn_rate=0.05, num_boost=200, subsample=0.75: 0.08874277599290861
# Mean Accuracy for max_depth=16, learn_rate=0.05, num_boost=200, subsample=1: 0.08511763114674484
# Mean Accuracy for max_depth=16, learn_rate=0.05, num_boost=250, subsample=0.75: 0.07396753340688778
# Mean Accuracy for max_depth=16, learn_rate=0.05, num_boost=250, subsample=1: 0.07132719973410823
# Mean Accuracy for max_depth=18, learn_rate=0.15, num_boost=100, subsample=0.75: 0.07124889892787009
# Mean Accuracy for max_depth=18, learn_rate=0.15, num_boost=100, subsample=1: 0.06861308321179319
# Mean Accuracy for max_depth=18, learn_rate=0.15, num_boost=150, subsample=0.75: 0.06774591923278148
# Mean Accuracy for max_depth=18, learn_rate=0.15, num_boost=150, subsample=1: 0.06584541500051261
# Mean Accuracy for max_depth=18, learn_rate=0.15, num_boost=200, subsample=0.75: 0.06676681902758089
# Mean Accuracy for max_depth=18, learn_rate=0.15, num_boost=200, subsample=1: 0.06508263711860252
# Mean Accuracy for max_depth=18, learn_rate=0.15, num_boost=250, subsample=0.75: 0.06615651053500486
# Mean Accuracy for max_depth=18, learn_rate=0.15, num_boost=250, subsample=1: 0.06453248637107745
# Mean Accuracy for max_depth=18, learn_rate=0.1, num_boost=100, subsample=0.75: 0.08941185473410597
# Mean Accuracy for max_depth=18, learn_rate=0.1, num_boost=100, subsample=1: 0.08574861466434147
# Mean Accuracy for max_depth=18, learn_rate=0.1, num_boost=150, subsample=0.75: 0.07125779382032685
# Mean Accuracy for max_depth=18, learn_rate=0.1, num_boost=150, subsample=1: 0.0686582202545023
# Mean Accuracy for max_depth=18, learn_rate=0.1, num_boost=200, subsample=0.75: 0.068420994821208
# Mean Accuracy for max_depth=18, learn_rate=0.1, num_boost=200, subsample=1: 0.06630616874756179
# Mean Accuracy for max_depth=18, learn_rate=0.1, num_boost=250, subsample=0.75: 0.06733265705778178
# Mean Accuracy for max_depth=18, learn_rate=0.1, num_boost=250, subsample=1: 0.06533592703907055
# Mean Accuracy for max_depth=18, learn_rate=0.05, num_boost=100, subsample=0.75: 0.7340143191192142
# Mean Accuracy for max_depth=18, learn_rate=0.05, num_boost=100, subsample=1: 0.7323873592531773
# Mean Accuracy for max_depth=18, learn_rate=0.05, num_boost=150, subsample=0.75: 0.18875301728207977
# Mean Accuracy for max_depth=18, learn_rate=0.05, num_boost=150, subsample=1: 0.18370239886926623
# Mean Accuracy for max_depth=18, learn_rate=0.05, num_boost=200, subsample=0.75: 0.08878770522396415
# Mean Accuracy for max_depth=18, learn_rate=0.05, num_boost=200, subsample=1: 0.0851387905459738
# Mean Accuracy for max_depth=18, learn_rate=0.05, num_boost=250, subsample=0.75: 0.07403568967847385
# Mean Accuracy for max_depth=18, learn_rate=0.05, num_boost=250, subsample=1: 0.07134484865897708
# Mean Accuracy for max_depth=24, learn_rate=0.15, num_boost=100, subsample=0.75: 0.07138299663577632
# Mean Accuracy for max_depth=24, learn_rate=0.15, num_boost=100, subsample=1: 0.06866450490557821
# Mean Accuracy for max_depth=24, learn_rate=0.15, num_boost=150, subsample=0.75: 0.06804565950598518
# Mean Accuracy for max_depth=24, learn_rate=0.15, num_boost=150, subsample=1: 0.06583443078741578
# Mean Accuracy for max_depth=24, learn_rate=0.15, num_boost=200, subsample=0.75: 0.06697075435366495
# Mean Accuracy for max_depth=24, learn_rate=0.15, num_boost=200, subsample=1: 0.06506438587228486
# Mean Accuracy for max_depth=24, learn_rate=0.15, num_boost=250, subsample=0.75: 0.0663569605520308
# Mean Accuracy for max_depth=24, learn_rate=0.15, num_boost=250, subsample=1: 0.0649100698691663
# Mean Accuracy for max_depth=24, learn_rate=0.1, num_boost=100, subsample=0.75: 0.08949016000048214
# Mean Accuracy for max_depth=24, learn_rate=0.1, num_boost=100, subsample=1: 0.08581768174315293
# Mean Accuracy for max_depth=24, learn_rate=0.1, num_boost=150, subsample=0.75: 0.0713135691485269
# Mean Accuracy for max_depth=24, learn_rate=0.1, num_boost=150, subsample=1: 0.06866126634938667
# Mean Accuracy for max_depth=24, learn_rate=0.1, num_boost=200, subsample=0.75: 0.06841143723088812
# Mean Accuracy for max_depth=24, learn_rate=0.1, num_boost=200, subsample=1: 0.06625817616616766
# Mean Accuracy for max_depth=24, learn_rate=0.1, num_boost=250, subsample=0.75: 0.06742503717710449
# Mean Accuracy for max_depth=24, learn_rate=0.1, num_boost=250, subsample=1: 0.06553705888502738
# Mean Accuracy for max_depth=24, learn_rate=0.05, num_boost=100, subsample=0.75: 0.7340140030038024
# Mean Accuracy for max_depth=24, learn_rate=0.05, num_boost=100, subsample=1: 0.7323387899569579
# Mean Accuracy for max_depth=24, learn_rate=0.05, num_boost=150, subsample=0.75: 0.18880322098708086
# Mean Accuracy for max_depth=24, learn_rate=0.05, num_boost=150, subsample=1: 0.18367254543943076
# Mean Accuracy for max_depth=24, learn_rate=0.05, num_boost=200, subsample=0.75: 0.08882500410868754
# Mean Accuracy for max_depth=24, learn_rate=0.05, num_boost=200, subsample=1: 0.08521891900276078
# Mean Accuracy for max_depth=24, learn_rate=0.05, num_boost=250, subsample=0.75: 0.07414154467396376
# Mean Accuracy for max_depth=24, learn_rate=0.05, num_boost=250, subsample=1: 0.0714107074413853
# Mean Accuracy for max_depth=28, learn_rate=0.15, num_boost=100, subsample=0.75: 0.0714765407693366
# Mean Accuracy for max_depth=28, learn_rate=0.15, num_boost=100, subsample=1: 0.06887112738238553
# Mean Accuracy for max_depth=28, learn_rate=0.15, num_boost=150, subsample=0.75: 0.06814444833042681
# Mean Accuracy for max_depth=28, learn_rate=0.15, num_boost=150, subsample=1: 0.06595342815437333
# Mean Accuracy for max_depth=28, learn_rate=0.15, num_boost=200, subsample=0.75: 0.06719884679348717
# Mean Accuracy for max_depth=28, learn_rate=0.15, num_boost=200, subsample=1: 0.06530987881968296
# Mean Accuracy for max_depth=28, learn_rate=0.15, num_boost=250, subsample=0.75: 0.06657135119713016
# Mean Accuracy for max_depth=28, learn_rate=0.15, num_boost=250, subsample=1: 0.06505375522502346
# Mean Accuracy for max_depth=28, learn_rate=0.1, num_boost=100, subsample=0.75: 0.08943346703658914
# Mean Accuracy for max_depth=28, learn_rate=0.1, num_boost=100, subsample=1: 0.08576030588539922
# Mean Accuracy for max_depth=28, learn_rate=0.1, num_boost=150, subsample=0.75: 0.07139632028503193
# Mean Accuracy for max_depth=28, learn_rate=0.1, num_boost=150, subsample=1: 0.0686477788067601
# Mean Accuracy for max_depth=28, learn_rate=0.1, num_boost=200, subsample=0.75: 0.06865885717536138
# Mean Accuracy for max_depth=28, learn_rate=0.1, num_boost=200, subsample=1: 0.0664750428476282
# Mean Accuracy for max_depth=28, learn_rate=0.1, num_boost=250, subsample=0.75: 0.06759202618470446
# Mean Accuracy for max_depth=28, learn_rate=0.1, num_boost=250, subsample=1: 0.06551752250470932
# Mean Accuracy for max_depth=28, learn_rate=0.05, num_boost=100, subsample=0.75: 0.734026840441735
# Mean Accuracy for max_depth=28, learn_rate=0.05, num_boost=100, subsample=1: 0.732387848669856
# Mean Accuracy for max_depth=28, learn_rate=0.05, num_boost=150, subsample=0.75: 0.18879088171676167
# Mean Accuracy for max_depth=28, learn_rate=0.05, num_boost=150, subsample=1: 0.18370952387807454
# Mean Accuracy for max_depth=28, learn_rate=0.05, num_boost=200, subsample=0.75: 0.0888262330894481
# Mean Accuracy for max_depth=28, learn_rate=0.05, num_boost=200, subsample=1: 0.08521772799140823
# Mean Accuracy for max_depth=28, learn_rate=0.05, num_boost=250, subsample=0.75: 0.07404606796691952
# Mean Accuracy for max_depth=28, learn_rate=0.05, num_boost=250, subsample=1: 0.07139017656257254
# The key with the minimum value is 'max_depth_16_learn_rate_0.15_num_boost_250_subsample_1' with a value of 0.06452192395398305.

# %%
max_depth = [14, 16, 18]
learning_rate = [0.2, 0.15, 0.1]
number_boosts = [225, 250, 275, 300, 1000]
subsamp = [0.8, 1]

model_err = {}

for md, lr, nbr, ss in itertools.product(max_depth, learning_rate, number_boosts, subsamp):
    # Initialize KFold
    kf = KFold(n_splits=5, shuffle=True)

    # Initialize a list to collect accuracy scores
    scores = []

    # Iterate over each fold
    for train_index, test_index in kf.split(X):

        X_train, X_test = X.loc[train_index], X.loc[test_index]
        y_train, y_test = y.loc[train_index], y.loc[test_index]

        dtrain = xgb.DMatrix(X_train, label=y_train, enable_categorical=True) 

                
        # Define parameters
        params = {
            'max_depth': md,
            'eta': lr,                           # learning rate
            'objective': 'reg:squaredlogerror',  # 
            'subsample': ss,                     # subsample rate
            'device': 'cuda'
        }

        # Initialize and train the model
        model = xgb.train(params, dtrain, num_boost_round=nbr)


        # Predict and evaluate the model
        y_pred = model.predict(xgb.DMatrix(X_test, enable_categorical=True))
        y_pred[y_pred <= 0] = 10
        score = rmsle(y_test, y_pred)
        scores.append(score)

            
    # Output the mean accuracy over all folds
    print(f"Mean Accuracy for max_depth={md}, learn_rate={lr}, num_boost={nbr}, subsample={ss}: {np.mean(scores)}")

    model_err[f"max_depth_{md}_learn_rate_{lr}_num_boost_{nbr}_subsample_{ss}"] = np.mean(scores)

# Find the key with the minimum value
min_key = min(model_err, key=model_err.get)

# Retrieve the minimum value
min_value = model_err[min_key]

# Print the result
print(f"The key with the minimum value is '{min_key}' with a value of {min_value}.")
# Out:
# Mean Accuracy for max_depth=14, learn_rate=0.2, num_boost=225, subsample=0.8: 0.06506856478335676
# Mean Accuracy for max_depth=14, learn_rate=0.2, num_boost=225, subsample=1: 0.06442764218267696
# Mean Accuracy for max_depth=14, learn_rate=0.2, num_boost=250, subsample=0.8: 0.06496931802766634
# Mean Accuracy for max_depth=14, learn_rate=0.2, num_boost=250, subsample=1: 0.06422704104292991
# Mean Accuracy for max_depth=14, learn_rate=0.2, num_boost=275, subsample=0.8: 0.0647997435506165
# Mean Accuracy for max_depth=14, learn_rate=0.2, num_boost=275, subsample=1: 0.06424150974769095
# Mean Accuracy for max_depth=14, learn_rate=0.2, num_boost=300, subsample=0.8: 0.0647455724207366
# Mean Accuracy for max_depth=14, learn_rate=0.2, num_boost=300, subsample=1: 0.06418509797130223
# Mean Accuracy for max_depth=14, learn_rate=0.2, num_boost=1000, subsample=0.8: 0.0649515875283648
# Mean Accuracy for max_depth=14, learn_rate=0.2, num_boost=1000, subsample=1: 0.06339094478537181
# Mean Accuracy for max_depth=14, learn_rate=0.15, num_boost=225, subsample=0.8: 0.0656067433255281
# Mean Accuracy for max_depth=14, learn_rate=0.15, num_boost=225, subsample=1: 0.0647348940066998
# Mean Accuracy for max_depth=14, learn_rate=0.15, num_boost=250, subsample=0.8: 0.06543673644911947
# Mean Accuracy for max_depth=14, learn_rate=0.15, num_boost=250, subsample=1: 0.06451403743684977
# Mean Accuracy for max_depth=14, learn_rate=0.15, num_boost=275, subsample=0.8: 0.06529882044457744
# Mean Accuracy for max_depth=14, learn_rate=0.15, num_boost=275, subsample=1: 0.06444121267866786
# Mean Accuracy for max_depth=14, learn_rate=0.15, num_boost=300, subsample=0.8: 0.06506027382032027
# Mean Accuracy for max_depth=14, learn_rate=0.15, num_boost=300, subsample=1: 0.0643910614623182
# Mean Accuracy for max_depth=14, learn_rate=0.15, num_boost=1000, subsample=0.8: 0.06439566560135257
# Mean Accuracy for max_depth=14, learn_rate=0.15, num_boost=1000, subsample=1: 0.0632988499704292
# Mean Accuracy for max_depth=14, learn_rate=0.1, num_boost=225, subsample=0.8: 0.06710639371395803
# Mean Accuracy for max_depth=14, learn_rate=0.1, num_boost=225, subsample=1: 0.06565754488115497
# Mean Accuracy for max_depth=14, learn_rate=0.1, num_boost=250, subsample=0.8: 0.06660689274816257
# Mean Accuracy for max_depth=14, learn_rate=0.1, num_boost=250, subsample=1: 0.065287356740474
# Mean Accuracy for max_depth=14, learn_rate=0.1, num_boost=275, subsample=0.8: 0.06607247196614768
# Mean Accuracy for max_depth=14, learn_rate=0.1, num_boost=275, subsample=1: 0.06514667622575805
# Mean Accuracy for max_depth=14, learn_rate=0.1, num_boost=300, subsample=0.8: 0.06596476959727127
# Mean Accuracy for max_depth=14, learn_rate=0.1, num_boost=300, subsample=1: 0.06495815645028775
# Mean Accuracy for max_depth=14, learn_rate=0.1, num_boost=1000, subsample=0.8: 0.06415361338698576
# Mean Accuracy for max_depth=14, learn_rate=0.1, num_boost=1000, subsample=1: 0.06341728773619366
# Mean Accuracy for max_depth=16, learn_rate=0.2, num_boost=225, subsample=0.8: 0.06522922645131056
# Mean Accuracy for max_depth=16, learn_rate=0.2, num_boost=225, subsample=1: 0.06453624271676188
# Mean Accuracy for max_depth=16, learn_rate=0.2, num_boost=250, subsample=0.8: 0.065203073328768
# Mean Accuracy for max_depth=16, learn_rate=0.2, num_boost=250, subsample=1: 0.06444290365702257
# Mean Accuracy for max_depth=16, learn_rate=0.2, num_boost=275, subsample=0.8: 0.06502329195980472
# Mean Accuracy for max_depth=16, learn_rate=0.2, num_boost=275, subsample=1: 0.0642011243376365
# Mean Accuracy for max_depth=16, learn_rate=0.2, num_boost=300, subsample=0.8: 0.06492728026380108
# Mean Accuracy for max_depth=16, learn_rate=0.2, num_boost=300, subsample=1: 0.0641218797497058
# Mean Accuracy for max_depth=16, learn_rate=0.2, num_boost=1000, subsample=0.8: 0.06514966855117103
# Mean Accuracy for max_depth=16, learn_rate=0.2, num_boost=1000, subsample=1: 0.06359881628665552
# Mean Accuracy for max_depth=16, learn_rate=0.15, num_boost=225, subsample=0.8: 0.06568473488713308
# Mean Accuracy for max_depth=16, learn_rate=0.15, num_boost=225, subsample=1: 0.06488179108885796
# Mean Accuracy for max_depth=16, learn_rate=0.15, num_boost=250, subsample=0.8: 0.065449172799288
# Mean Accuracy for max_depth=16, learn_rate=0.15, num_boost=250, subsample=1: 0.0645849983243929
# Mean Accuracy for max_depth=16, learn_rate=0.15, num_boost=275, subsample=0.8: 0.06524905568022503
# Mean Accuracy for max_depth=16, learn_rate=0.15, num_boost=275, subsample=1: 0.06432881221984015
# Mean Accuracy for max_depth=16, learn_rate=0.15, num_boost=300, subsample=0.8: 0.0650923368046445
# Mean Accuracy for max_depth=16, learn_rate=0.15, num_boost=300, subsample=1: 0.06421019528071743
# Mean Accuracy for max_depth=16, learn_rate=0.15, num_boost=1000, subsample=0.8: 0.06467510065640819
# Mean Accuracy for max_depth=16, learn_rate=0.15, num_boost=1000, subsample=1: 0.0634134202527745
# Mean Accuracy for max_depth=16, learn_rate=0.1, num_boost=225, subsample=0.8: 0.06704275727476036
# Mean Accuracy for max_depth=16, learn_rate=0.1, num_boost=225, subsample=1: 0.0656729651261628
# Mean Accuracy for max_depth=16, learn_rate=0.1, num_boost=250, subsample=0.8: 0.06660741279605759
# Mean Accuracy for max_depth=16, learn_rate=0.1, num_boost=250, subsample=1: 0.06529125059832579
# Mean Accuracy for max_depth=16, learn_rate=0.1, num_boost=275, subsample=0.8: 0.06616476993329025
# Mean Accuracy for max_depth=16, learn_rate=0.1, num_boost=275, subsample=1: 0.06521751645032617
# Mean Accuracy for max_depth=16, learn_rate=0.1, num_boost=300, subsample=0.8: 0.06581413459999683
# Mean Accuracy for max_depth=16, learn_rate=0.1, num_boost=300, subsample=1: 0.06486930568964228
# Mean Accuracy for max_depth=16, learn_rate=0.1, num_boost=1000, subsample=0.8: 0.06439614145060468
# Mean Accuracy for max_depth=16, learn_rate=0.1, num_boost=1000, subsample=1: 0.0635868347030291
# Mean Accuracy for max_depth=18, learn_rate=0.2, num_boost=225, subsample=0.8: 0.0653646394041473
# Mean Accuracy for max_depth=18, learn_rate=0.2, num_boost=225, subsample=1: 0.06467115358781508
# Mean Accuracy for max_depth=18, learn_rate=0.2, num_boost=250, subsample=0.8: 0.06524599529293452
# Mean Accuracy for max_depth=18, learn_rate=0.2, num_boost=250, subsample=1: 0.06439266049447853
# Mean Accuracy for max_depth=18, learn_rate=0.2, num_boost=275, subsample=0.8: 0.06516040230211526
# Mean Accuracy for max_depth=18, learn_rate=0.2, num_boost=275, subsample=1: 0.06435495549628459
# Mean Accuracy for max_depth=18, learn_rate=0.2, num_boost=300, subsample=0.8: 0.06505199642903663
# Mean Accuracy for max_depth=18, learn_rate=0.2, num_boost=300, subsample=1: 0.0642385504999671
# Mean Accuracy for max_depth=18, learn_rate=0.2, num_boost=1000, subsample=0.8: 0.06549436614468851
# Mean Accuracy for max_depth=18, learn_rate=0.2, num_boost=1000, subsample=1: 0.06378324497782002
# Mean Accuracy for max_depth=18, learn_rate=0.15, num_boost=225, subsample=0.8: 0.065875196661205
# Mean Accuracy for max_depth=18, learn_rate=0.15, num_boost=225, subsample=1: 0.06474542383859186
# Mean Accuracy for max_depth=18, learn_rate=0.15, num_boost=250, subsample=0.8: 0.06551428413903437
# Mean Accuracy for max_depth=18, learn_rate=0.15, num_boost=250, subsample=1: 0.06467202288531415
# Mean Accuracy for max_depth=18, learn_rate=0.15, num_boost=275, subsample=0.8: 0.06540092506795384
# Mean Accuracy for max_depth=18, learn_rate=0.15, num_boost=275, subsample=1: 0.06447904521825439
# Mean Accuracy for max_depth=18, learn_rate=0.15, num_boost=300, subsample=0.8: 0.06521917771262269
# Mean Accuracy for max_depth=18, learn_rate=0.15, num_boost=300, subsample=1: 0.06420803827992255
# Mean Accuracy for max_depth=18, learn_rate=0.15, num_boost=1000, subsample=0.8: 0.06508733872463204
# Mean Accuracy for max_depth=18, learn_rate=0.15, num_boost=1000, subsample=1: 0.06368698819778093
# Mean Accuracy for max_depth=18, learn_rate=0.1, num_boost=225, subsample=0.8: 0.06713057155854085
# Mean Accuracy for max_depth=18, learn_rate=0.1, num_boost=225, subsample=1: 0.06577703895508988
# Mean Accuracy for max_depth=18, learn_rate=0.1, num_boost=250, subsample=0.8: 0.066627944821577
# Mean Accuracy for max_depth=18, learn_rate=0.1, num_boost=250, subsample=1: 0.06543991115927651
# Mean Accuracy for max_depth=18, learn_rate=0.1, num_boost=275, subsample=0.8: 0.06623434636068745
# Mean Accuracy for max_depth=18, learn_rate=0.1, num_boost=275, subsample=1: 0.06503057254641546
# Mean Accuracy for max_depth=18, learn_rate=0.1, num_boost=300, subsample=0.8: 0.0658991891388542
# Mean Accuracy for max_depth=18, learn_rate=0.1, num_boost=300, subsample=1: 0.06491314302142184
# Mean Accuracy for max_depth=18, learn_rate=0.1, num_boost=1000, subsample=0.8: 0.06460509462723696
# Mean Accuracy for max_depth=18, learn_rate=0.1, num_boost=1000, subsample=1: 0.06366132317065458
# The key with the minimum value is 'max_depth_14_learn_rate_0.15_num_boost_1000_subsample_1' with a value of 0.0632988499704292.

# %%
max_depth = [14, 15]
learning_rate = [0.2, 0.15, 0.1]
number_boosts = [500, 1000, 1500, 2000]
subsamp = [0.8, 1]

model_err = {}

for md, lr, nbr, ss in itertools.product(max_depth, learning_rate, number_boosts, subsamp):
    # Initialize KFold
    kf = KFold(n_splits=5, shuffle=True)

    # Initialize a list to collect accuracy scores
    scores = []

    # Iterate over each fold
    for train_index, test_index in kf.split(X):

        X_train, X_test = X.loc[train_index], X.loc[test_index]
        y_train, y_test = y.loc[train_index], y.loc[test_index]

        dtrain = xgb.DMatrix(X_train, label=y_train, enable_categorical=True) 

                
        # Define parameters
        params = {
            'max_depth': md,
            'eta': lr,                           # learning rate
            'objective': 'reg:squaredlogerror',  # 
            'subsample': ss,                     # subsample rate
            'device': 'cuda'
        }

        # Initialize and train the model
        model = xgb.train(params, dtrain, num_boost_round=nbr)


        # Predict and evaluate the model
        y_pred = model.predict(xgb.DMatrix(X_test, enable_categorical=True))
        y_pred[y_pred <= 0] = 10
        score = rmsle(y_test, y_pred)
        scores.append(score)

            
    # Output the mean accuracy over all folds
    print(f"Mean Accuracy for max_depth={md}, learn_rate={lr}, num_boost={nbr}, subsample={ss}: {np.mean(scores)}")

    model_err[f"max_depth_{md}_learn_rate_{lr}_num_boost_{nbr}_subsample_{ss}"] = np.mean(scores)

# Find the key with the minimum value
min_key = min(model_err, key=model_err.get)

# Retrieve the minimum value
min_value = model_err[min_key]

# Print the result
print(f"The key with the minimum value is '{min_key}' with a value of {min_value}.")
# Out:
# Mean Accuracy for max_depth=14, learn_rate=0.2, num_boost=500, subsample=0.8: 0.06441515483010365
# Mean Accuracy for max_depth=14, learn_rate=0.2, num_boost=500, subsample=1: 0.0635822096060801
# Mean Accuracy for max_depth=14, learn_rate=0.2, num_boost=1000, subsample=0.8: 0.06481563594247756
# Mean Accuracy for max_depth=14, learn_rate=0.2, num_boost=1000, subsample=1: 0.06336872793337091
# Mean Accuracy for max_depth=14, learn_rate=0.2, num_boost=1500, subsample=0.8: 0.0654725724321548
# Mean Accuracy for max_depth=14, learn_rate=0.2, num_boost=1500, subsample=1: 0.0635204994150172
# Mean Accuracy for max_depth=14, learn_rate=0.2, num_boost=2000, subsample=0.8: 0.06602025240436285
# Mean Accuracy for max_depth=14, learn_rate=0.2, num_boost=2000, subsample=1: 0.06384522940595323
# Mean Accuracy for max_depth=14, learn_rate=0.15, num_boost=500, subsample=0.8: 0.06441013454644193
# Mean Accuracy for max_depth=14, learn_rate=0.15, num_boost=500, subsample=1: 0.0636903812917079
# Mean Accuracy for max_depth=14, learn_rate=0.15, num_boost=1000, subsample=0.8: 0.06443766681639282
# Mean Accuracy for max_depth=14, learn_rate=0.15, num_boost=1000, subsample=1: 0.0632569956756952
# Mean Accuracy for max_depth=14, learn_rate=0.15, num_boost=1500, subsample=0.8: 0.06489069260359479
# Mean Accuracy for max_depth=14, learn_rate=0.15, num_boost=1500, subsample=1: 0.06319112947255254
# Mean Accuracy for max_depth=14, learn_rate=0.15, num_boost=2000, subsample=0.8: 0.06521932485866044
# Mean Accuracy for max_depth=14, learn_rate=0.15, num_boost=2000, subsample=1: 0.06332589928114121
# Mean Accuracy for max_depth=14, learn_rate=0.1, num_boost=500, subsample=0.8: 0.06468692143417189
# Mean Accuracy for max_depth=14, learn_rate=0.1, num_boost=500, subsample=1: 0.06410187429060976
# Mean Accuracy for max_depth=14, learn_rate=0.1, num_boost=1000, subsample=0.8: 0.06412843913799411
# Mean Accuracy for max_depth=14, learn_rate=0.1, num_boost=1000, subsample=1: 0.06337192875985928
# Mean Accuracy for max_depth=14, learn_rate=0.1, num_boost=1500, subsample=0.8: 0.0642420472901667
# Mean Accuracy for max_depth=14, learn_rate=0.1, num_boost=1500, subsample=1: 0.06322515998628739
# Mean Accuracy for max_depth=14, learn_rate=0.1, num_boost=2000, subsample=0.8: 0.06455792295804032
# Mean Accuracy for max_depth=14, learn_rate=0.1, num_boost=2000, subsample=1: 0.06312132821817121
# Mean Accuracy for max_depth=15, learn_rate=0.2, num_boost=500, subsample=0.8: 0.06472714843347019
# Mean Accuracy for max_depth=15, learn_rate=0.2, num_boost=500, subsample=1: 0.06364839197678344
# Mean Accuracy for max_depth=15, learn_rate=0.2, num_boost=1000, subsample=0.8: 0.06513854311136963
# Mean Accuracy for max_depth=15, learn_rate=0.2, num_boost=1000, subsample=1: 0.06350739312242257
# Mean Accuracy for max_depth=15, learn_rate=0.2, num_boost=1500, subsample=0.8: 0.06547310089668201
# Mean Accuracy for max_depth=15, learn_rate=0.2, num_boost=1500, subsample=1: 0.06370538145708114
# Mean Accuracy for max_depth=15, learn_rate=0.2, num_boost=2000, subsample=0.8: 0.06605984127108475
# Mean Accuracy for max_depth=15, learn_rate=0.2, num_boost=2000, subsample=1: 0.06394015948132442
# Mean Accuracy for max_depth=15, learn_rate=0.15, num_boost=500, subsample=0.8: 0.06450115862379263
# Mean Accuracy for max_depth=15, learn_rate=0.15, num_boost=500, subsample=1: 0.06378021998931335
# Mean Accuracy for max_depth=15, learn_rate=0.15, num_boost=1000, subsample=0.8: 0.06461514472408296
# Mean Accuracy for max_depth=15, learn_rate=0.15, num_boost=1000, subsample=1: 0.06337229880357184
# Mean Accuracy for max_depth=15, learn_rate=0.15, num_boost=1500, subsample=0.8: 0.06505653774360583
# Mean Accuracy for max_depth=15, learn_rate=0.15, num_boost=1500, subsample=1: 0.06337843213964986
# Mean Accuracy for max_depth=15, learn_rate=0.15, num_boost=2000, subsample=0.8: 0.06554288494597897
# Mean Accuracy for max_depth=15, learn_rate=0.15, num_boost=2000, subsample=1: 0.06346524226827155
# Mean Accuracy for max_depth=15, learn_rate=0.1, num_boost=500, subsample=0.8: 0.0646391787683837
# Mean Accuracy for max_depth=15, learn_rate=0.1, num_boost=500, subsample=1: 0.06417282561135812
# Mean Accuracy for max_depth=15, learn_rate=0.1, num_boost=1000, subsample=0.8: 0.06425445026937451
# Mean Accuracy for max_depth=15, learn_rate=0.1, num_boost=1000, subsample=1: 0.06344737022622855
# Mean Accuracy for max_depth=15, learn_rate=0.1, num_boost=1500, subsample=0.8: 0.06447592143169718
# Mean Accuracy for max_depth=15, learn_rate=0.1, num_boost=1500, subsample=1: 0.06329796222027251
# Mean Accuracy for max_depth=15, learn_rate=0.1, num_boost=2000, subsample=0.8: 0.06474662152683035
# Mean Accuracy for max_depth=15, learn_rate=0.1, num_boost=2000, subsample=1: 0.06328531242351323
# The key with the minimum value is 'max_depth_14_learn_rate_0.1_num_boost_2000_subsample_1' with a value of 0.06312132821817121.

# %%
X_train = train.sample(n=600000, random_state=212)
y_train = X_train['Calories']

X_train.drop(columns=['id', 'Calories'], inplace=True)
X_train['Sex'] = X_train['Sex'].astype('category')
X_train['BMI'] = X_train['Weight']/((X_train['Height']/100)**2)
X_train['Intensity'] = X_train['Duration']*X_train['Heart_Rate']

X_train.head()
# Out:
#            Sex  Age  Height  Weight  Duration  Heart_Rate  Body_Temp  \
# 637285    male   40   182.0    85.0      16.0        91.0       40.2
# 137087  female   30   158.0    64.0      10.0        90.0       40.2
# 11662     male   54   184.0    87.0       3.0        82.0       38.8
# 83022   female   61   186.0    81.0      25.0       106.0       40.7
# 405249  female   40   169.0    69.0      11.0        99.0       39.9
#
#               BMI  Intensity
# 637285  25.661152     1456.0
# 137087  25.636917      900.0
# 11662   25.697070      246.0
# 83022   23.413111     2650.0
# 405249  24.158818     1089.0

# %%
# kaggle score: 0.06241

dtrain = xgb.DMatrix(X_train, label=y_train, enable_categorical=True)

params = {'max_depth': 16,
          'eta': 0.2,
          'objective': 'reg:squaredlogerror',
          'subsample': 1,
          'device': 'cuda',
          #'tree_method': 'hist'
          }

model = xgb.train(params, dtrain, num_boost_round=300)

test_pred = model.predict(xgb.DMatrix(X_train, enable_categorical=True))
test_pred[test_pred < 0] = 10

print(rmsle(test_pred, y_train))
# Out:
# 0.05902165692861264

# %%
# kaggle score: 0.06144

dtrain = xgb.DMatrix(X_train, label=y_train, enable_categorical=True)

params = {'max_depth': 14,
          'eta': 0.15,
          'objective': 'reg:squaredlogerror',
          'subsample': 1,
          'device': 'cuda',
          #'tree_method': 'hist'
          }

model = xgb.train(params, dtrain, num_boost_round=1000)

test_pred = model.predict(xgb.DMatrix(X_train, enable_categorical=True))
test_pred[test_pred < 0] = 10

print(rmsle(test_pred, y_train))
# Out:
# 0.05659396607442609

# %%
# kaggle score: 0.06101

dtrain = xgb.DMatrix(X_train, label=y_train, enable_categorical=True)

params = {'max_depth': 14,
          'eta': 0.1,
          'objective': 'reg:squaredlogerror',
          'subsample': 1,
          'device': 'cuda',
          #'tree_method': 'hist'
          }

model = xgb.train(params, dtrain, num_boost_round=2000)

test_pred = model.predict(xgb.DMatrix(X_train, enable_categorical=True))
test_pred[test_pred < 0] = 10

print(rmsle(test_pred, y_train))
# Out:
# 0.05581408345720477

# %%
# kaggle score: 0.06287

dtrain = xgb.DMatrix(X_train, label=y_train, enable_categorical=True)

params = {'max_depth': 32,
          'eta': 0.2,
          'objective': 'reg:squaredlogerror',
          #'device': 'cuda',
          #'tree_method': 'gpu_hist'
          }

model = xgb.train(params, dtrain, num_boost_round=600)

test_pred = model.predict(xgb.DMatrix(X_train, enable_categorical=True))
test_pred[test_pred < 0] = 0

print(rmsle(test_pred, y_train))
# Out:
# 0.05182231960216766

# %%
# kaggle score: 0.06409

dtrain = xgb.DMatrix(X_train, label=y_train, enable_categorical=True)

params = {'max_depth': 64,
          'eta': 0.2,
          'objective': 'reg:squaredlogerror',
          #'device': 'cuda',
          #'tree_method': 'gpu_hist'
          }

model = xgb.train(params, dtrain, num_boost_round=600)

test_pred = model.predict(xgb.DMatrix(X_train, enable_categorical=True))
test_pred[test_pred < 0] = 0

print(rmsle(test_pred, y_train))
# Out:
# 0.04930453294486195

# %%
# kaggle score: 0.06297

dtrain = xgb.DMatrix(X_train, label=y_train, enable_categorical=True)

params = {'max_depth': 32,
          'eta': 0.1,
          'objective': 'reg:squaredlogerror',
          #'device': 'cuda',
          #'tree_method': 'gpu_hist'
          }

model = xgb.train(params, dtrain, num_boost_round=600)

test_pred = model.predict(xgb.DMatrix(X_train, enable_categorical=True))
test_pred[test_pred < 0] = 0

print(rmsle(test_pred, y_train))
# Out:
# 0.05531693824542557

# %%
# kaggle score: 0.06390

dtrain = xgb.DMatrix(X_train, label=y_train, enable_categorical=True)

params = {'max_depth': 64,
          'eta': 0.1,
          'objective': 'reg:squaredlogerror',
          #'device': 'cuda',
          #'tree_method': 'gpu_hist'
          }

model = xgb.train(params, dtrain, num_boost_round=600)

test_pred = model.predict(xgb.DMatrix(X_train, enable_categorical=True))
test_pred[test_pred < 0] = 0

print(rmsle(test_pred, y_train))
# Out:
# 0.052893620059793325

# %%
# kaggle score: 0.06414

dtrain = xgb.DMatrix(X_train, label=y_train, enable_categorical=True)

params = {'max_depth': 64,
          'eta': 0.1,
          'objective': 'reg:squaredlogerror',
          #'device': 'cuda',
          #'tree_method': 'gpu_hist'
          }

model = xgb.train(params, dtrain, num_boost_round=400)

test_pred = model.predict(xgb.DMatrix(X_train, enable_categorical=True))
test_pred[test_pred < 0] = 0

print(rmsle(test_pred, y_train))
# Out:
# 0.05502459247082603

# %%
test.drop(columns=['id'], inplace=True)

test['Sex'] = test['Sex'].astype('category')
test['BMI'] = test['Weight']/((test['Height']/100)**2)
test['Intensity'] = test['Duration']*test['Heart_Rate']

test.head()
# Out:
#       Sex  Age  Height  Weight  Duration  Heart_Rate  Body_Temp        BMI  \
# 0    male   45   177.0    81.0       7.0        87.0       39.8  25.854639
# 1    male   26   200.0    97.0      20.0       101.0       40.5  24.250000
# 2  female   29   188.0    85.0      16.0       102.0       40.4  24.049344
# 3  female   39   172.0    73.0      20.0       107.0       40.6  24.675500
# 4  female   30   173.0    67.0      16.0        94.0       40.5  22.386314
#
#    Intensity
# 0      609.0
# 1     2020.0
# 2     1632.0
# 3     2140.0
# 4     1504.0

# %%
# make the submission file!

pred = model.predict(xgb.DMatrix(test, enable_categorical=True))

submission = pd.DataFrame()

submission['id'] = np.arange(len(test))+750000
submission['Calories'] = pred
submission.loc[submission['Calories'] < 0, 'Calories'] = 10

submission.to_csv("xgb_prediction_10.csv", index=False)

print(submission.head())
print()
print(submission['Calories'].describe())
# Out:
#        id    Calories
# 0  750000   27.663424
# 1  750001  110.360237
# 2  750002   86.528763
# 3  750003  125.446068
# 4  750004   76.078491
#
# count    250000.000000
# mean         88.096863
# std          61.928688
# min           0.796141
# 25%          34.031651
# 50%          76.446026
# 75%         135.274139
# max         246.989044
# Name: Calories, dtype: float64
